# %% [markdown]
# <a href="https://colab.research.google.com/github/AlijaNoushad/Alija-assignments-casestudy/blob/main/preprocessingassignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

data = pd.read_csv('/content/titanic_dataset.csv')

data.set_index('PassengerId', inplace=True)
print("Data with 'PassengerId' as index:\n", data.head())

print("\nData Information:\n")
print(data.info())
print("\nSummary Statistics:\n", data.describe())

for column in data.columns:
    if data[column].dtype == 'object':
        data[column].fillna(data[column].mode()[0], inplace=True)
    else:
        data[column].fillna(data[column].median(), inplace=True)
print("\nData after filling missing values:\n", data.head())

def cap_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
    df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])
    return df

columns_to_cap = ['Age', 'Fare', 'SibSp']
for column in columns_to_cap:
    data = cap_outliers(data, column)
print("\nData after handling outliers:\n", data[columns_to_cap].head())

scaler = MinMaxScaler()
features = data.drop('Survived', axis=1)
target = data['Survived']
features_scaled = pd.DataFrame(scaler.fit_transform(features_to_scale),columns=features_to_scale.columns,index=features.index)
print("\nScaled Features:\n", features_scaled.head())
# Out:
# Data with 'PassengerId' as index:
#               Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...
